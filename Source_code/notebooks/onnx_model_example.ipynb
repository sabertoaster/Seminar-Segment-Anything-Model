# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# # Produces masks from prompts using an ONNX model

# %% [markdown]
# SAM's prompt encoder and mask decoder are very lightweight, which allows for efficient computation of a mask given user input. This notebook shows an example of how to export and use this lightweight component of the model in ONNX format, allowing it to run on a variety of platforms that support an ONNX runtime.

# %%
from IPython.display import display, HTML
display(HTML(
"""
<a target="_blank" href="https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/onnx_model_example.ipynb">
  <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
</a>
"""
))
# Out:
# <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/onnx_model_example.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Environment Set-up

# %% [markdown]
# If running locally using jupyter, first install `segment_anything` in your environment using the [installation instructions](https://github.com/facebookresearch/segment-anything#installation) in the repository. The latest stable versions of PyTorch and ONNX are recommended for this notebook. If running from Google Colab, set `using_colab=True` below and run the cell. In Colab, be sure to select 'GPU' under 'Edit'->'Notebook Settings'->'Hardware accelerator'.

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib onnx onnxruntime
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything.git'
    
    # !mkdir images
    # !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/truck.jpg
        
    # !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth

# %% [markdown]
# ## Set-up

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root))

# %% [markdown]
# Note that this notebook requires both the `onnx` and `onnxruntime` optional dependencies, in addition to `opencv-python` and `matplotlib` for visualization.

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
from segment_anything import sam_model_registry, SamPredictor
from segment_anything.utils.onnx import SamOnnxModel

import onnxruntime
from onnxruntime.quantization import QuantType
from onnxruntime.quantization.quantize import quantize_dynamic

# %%
def show_mask(mask, ax):
    color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)
    
def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)   
    
def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %% [markdown]
# ## Export an ONNX model

# %% [markdown]
# Set the path below to a SAM model checkpoint, then load the model. This will be needed to both export the model and to calculate embeddings for the model.

# %%
checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"

# %%
sam = sam_model_registry[model_type](checkpoint=checkpoint)

# %% [markdown]
# The script `segment-anything/scripts/export_onnx_model.py` can be used to export the necessary portion of SAM. Alternatively, run the following code to export an ONNX model. If you have already exported a model, set the path below and skip to the next section. Assure that the exported ONNX model aligns with the checkpoint and model type set above. This notebook expects the model was exported with the parameter `return_single_mask=True`.

# %%
onnx_model_path = None  # Set to use an already exported model, then skip to the next section.

# %%
import warnings

onnx_model_path = "sam_onnx_example.onnx"

onnx_model = SamOnnxModel(sam, return_single_mask=True)

dynamic_axes = {
    "point_coords": {1: "num_points"},
    "point_labels": {1: "num_points"},
}

embed_dim = sam.prompt_encoder.embed_dim
embed_size = sam.prompt_encoder.image_embedding_size
mask_input_size = [4 * x for x in embed_size]
dummy_inputs = {
    "image_embeddings": torch.randn(1, embed_dim, *embed_size, dtype=torch.float),
    "point_coords": torch.randint(low=0, high=1024, size=(1, 5, 2), dtype=torch.float),
    "point_labels": torch.randint(low=0, high=4, size=(1, 5), dtype=torch.float),
    "mask_input": torch.randn(1, 1, *mask_input_size, dtype=torch.float),
    "has_mask_input": torch.tensor([1], dtype=torch.float),
    "orig_im_size": torch.tensor([1500, 2250], dtype=torch.float),
}
output_names = ["masks", "iou_predictions", "low_res_masks"]

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=torch.jit.TracerWarning)
    warnings.filterwarnings("ignore", category=UserWarning)
    with open(onnx_model_path, "wb") as f:
        torch.onnx.export(
            onnx_model,
            tuple(dummy_inputs.values()),
            f,
            export_params=True,
            verbose=False,
            opset_version=17,
            do_constant_folding=True,
            input_names=list(dummy_inputs.keys()),
            output_names=output_names,
            dynamic_axes=dynamic_axes,
        )
# Out:
# W0113 17:46:41.631000 23760 Lib\site-packages\torch\onnx\_internal\exporter\_compat.py:114] Setting ONNX exporter to use operator set version 18 because the requested opset_version 13 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# W0113 17:46:42.926000 23760 Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:7942] Unable to find user code corresponding to {u0}
#
#
#
# def forward(self, arg0_1: "f32[256, 256]", arg1_1: "f32[256]", arg2_1: "f32[256, 256]", arg3_1: "f32[256]", arg4_1: "f32[256, 256]", arg5_1: "f32[256]", arg6_1: "f32[256, 256]", arg7_1: "f32[256]", arg8_1: "f32[256]", arg9_1: "f32[256]", arg10_1: "f32[128, 256]", arg11_1: "f32[128]", arg12_1: "f32[128, 256]", arg13_1: "f32[128]", arg14_1: "f32[128, 256]", arg15_1: "f32[128]", arg16_1: "f32[256, 128]", arg17_1: "f32[256]", arg18_1: "f32[256]", arg19_1: "f32[256]", arg20_1: "f32[2048, 256]", arg21_1: "f32[2048]", arg22_1: "f32[256, 2048]", arg23_1: "f32[256]", arg24_1: "f32[256]", arg25_1: "f32[256]", arg26_1: "f32[256]", arg27_1: "f32[256]", arg28_1: "f32[128, 256]", arg29_1: "f32[128]", arg30_1: "f32[128, 256]", arg31_1: "f32[128]", arg32_1: "f32[128, 256]", arg33_1: "f32[128]", arg34_1: "f32[256, 128]", arg35_1: "f32[256]", arg36_1: "f32[256, 256]", arg37_1: "f32[256]", arg38_1: "f32[256, 256]", arg39_1: "f32[256]", arg40_1: "f32[256, 256]", arg41_1: "f32[256]", arg42_1: "f32[256, 256]", arg43_1: "f32[256]", arg44_1: "f32[256]", arg45_1: "f32[256]", arg46_1: "f32[128, 256]", arg47_1: "f32[128]", arg48_1: "f32[128, 256]", arg49_1: "f32[128]", arg50_1: "f32[128, 256]", arg51_1: "f32[128]", arg52_1: "f32[256, 128]", arg53_1: "f32[256]", arg54_1: "f32[256]", arg55_1: "f32[256]", arg56_1: "f32[2048, 256]", arg57_1: "f32[2048]", arg58_1: "f32[256, 2048]", arg59_1: "f32[256]", arg60_1: "f32[256]", arg61_1: "f32[256]", arg62_1: "f32[256]", arg63_1: "f32[256]", arg64_1: "f32[128, 256]", arg65_1: "f32[128]", arg66_1: "f32[128, 256]", arg67_1: "f32[128]", arg68_1: "f32[128, 256]", arg69_1: "f32[128]", arg70_1: "f32[256, 128]", arg71_1: "f32[256]", arg72_1: "f32[128, 256]", arg73_1: "f32[128]", arg74_1: "f32[128, 256]", arg75_1: "f32[128]", arg76_1: "f32[128, 256]", arg77_1: "f32[128]", arg78_1: "f32[256, 128]", arg79_1: "f32[256]", arg80_1: "f32[256]", arg81_1: "f32[256]", arg82_1: "f32[1, 256]", arg83_1: "f32[4, 256]", arg84_1: "f32[256, 64, 2, 2]", arg85_1: "f32[64]", arg86_1: "f32[64]", arg87_1: "f32[64]", arg88_1: "f32[64, 32, 2, 2]", arg89_1: "f32[32]", arg90_1: "f32[256, 256]", arg91_1: "f32[256]", arg92_1: "f32[256, 256]", arg93_1: "f32[256]", arg94_1: "f32[32, 256]", arg95_1: "f32[32]", arg96_1: "f32[256, 256]", arg97_1: "f32[256]", arg98_1: "f32[256, 256]", arg99_1: "f32[256]", arg100_1: "f32[32, 256]", arg101_1: "f32[32]", arg102_1: "f32[256, 256]", arg103_1: "f32[256]", arg104_1: "f32[256, 256]", arg105_1: "f32[256]", arg106_1: "f32[32, 256]", arg107_1: "f32[32]", arg108_1: "f32[256, 256]", arg109_1: "f32[256]", arg110_1: "f32[256, 256]", arg111_1: "f32[256]", arg112_1: "f32[32, 256]", arg113_1: "f32[32]", arg114_1: "f32[256, 256]", arg115_1: "f32[256]", arg116_1: "f32[256, 256]", arg117_1: "f32[256]", arg118_1: "f32[4, 256]", arg119_1: "f32[4]", arg120_1: "f32[1, 64, 64, 1280]", arg121_1: "f32[1280, 3, 16, 16]", arg122_1: "f32[1280]", arg123_1: "f32[1280]", arg124_1: "f32[1280]", arg125_1: "f32[27, 80]", arg126_1: "f32[27, 80]", arg127_1: "f32[3840, 1280]", arg128_1: "f32[3840]", arg129_1: "f32[1280, 1280]", arg130_1: "f32[1280]", arg131_1: "f32[1280]", arg132_1: "f32[1280]", arg133_1: "f32[5120, 1280]", arg134_1: "f32[5120]", arg135_1: "f32[1280, 5120]", arg136_1: "f32[1280]", arg137_1: "f32[1280]", arg138_1: "f32[1280]", arg139_1: "f32[27, 80]", arg140_1: "f32[27, 80]", arg141_1: "f32[3840, 1280]", arg142_1: "f32[3840]", arg143_1: "f32[1280, 1280]", arg144_1: "f32[1280]", arg145_1: "f32[1280]", arg146_1: "f32[1280]", arg147_1: "f32[5120, 1280]", arg148_1: "f32[5120]", arg149_1: "f32[1280, 5120]", arg150_1: "f32[1280]", arg151_1: "f32[1280]", arg152_1: "f32[1280]", arg153_1: "f32[27, 80]", arg154_1: "f32[27, 80]", arg155_1: "f32[3840, 1280]", arg156_1: "f32[3840]", arg157_1: "f32[1280, 1280]", arg158_1: "f32[1280]", arg159_1: "f32[1280]", arg160_1: "f32[1280]", arg161_1: "f32[5120, 1280]", arg162_1: "f32[5120]", arg163_1: "f32[1280, 5120]", arg164_1: "f32[1280]", arg165_1: "f32[1280]", arg166_1: "f32[1280]", arg167_1: "f32[ ...
#     # No stacktrace found for following nodes
#     _set_grad_enabled = torch._C._set_grad_enabled(False);  _set_grad_enabled = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py:117 in forward, code: sparse_embedding = self._embed_points(point_coords, point_labels)
#     add: "f32[1, 5, 2]" = torch.ops.aten.add.Tensor(arg717_1, 0.5)
#     div: "f32[1, 5, 2]" = torch.ops.aten.div.Tensor(add, 1024);  add = None
#     mul: "f32[1, 5, 2]" = torch.ops.aten.mul.Tensor(div, 2);  div = None
#     sub: "f32[1, 5, 2]" = torch.ops.aten.sub.Tensor(mul, 1);  mul = None
#     matmul: "f32[1, 5, 128]" = torch.ops.aten.matmul.default(sub, arg715_1);  sub = None
#     mul_1: "f32[1, 5, 128]" = torch.ops.aten.mul.Tensor(matmul, 6.283185307179586);  matmul = None
#     sin: "f32[1, 5, 128]" = torch.ops.aten.sin.default(mul_1)
#     cos: "f32[1, 5, 128]" = torch.ops.aten.cos.default(mul_1);  mul_1 = None
#     cat: "f32[1, 5, 256]" = torch.ops.aten.cat.default([sin, cos], -1);  sin = cos = None
#     unsqueeze: "f32[1, 5, 1]" = torch.ops.aten.unsqueeze.default(arg718_1, -1);  arg718_1 = None
#     expand_as: "f32[1, 5, 256]" = torch.ops.aten.expand_as.default(unsqueeze, cat);  unsqueeze = None
#     ne: "b8[1, 5, 256]" = torch.ops.aten.ne.Scalar(expand_as, -1)
#     mul_2: "f32[1, 5, 256]" = torch.ops.aten.mul.Tensor(cat, ne);  cat = ne = None
#     eq: "b8[1, 5, 256]" = torch.ops.aten.eq.Scalar(expand_as, -1)
#     mul_3: "f32[1, 5, 256]" = torch.ops.aten.mul.Tensor(arg581_1, eq);  arg581_1 = eq = None
#     add_1: "f32[1, 5, 256]" = torch.ops.aten.add.Tensor(mul_2, mul_3);  mul_2 = mul_3 = None
#     eq_1: "b8[1, 5, 256]" = torch.ops.aten.eq.Scalar(expand_as, 0)
#     mul_4: "f32[1, 5, 256]" = torch.ops.aten.mul.Tensor(arg577_1, eq_1);  arg577_1 = eq_1 = None
#     add_2: "f32[1, 5, 256]" = torch.ops.aten.add.Tensor(add_1, mul_4);  add_1 = mul_4 = None
#     eq_2: "b8[1, 5, 256]" = torch.ops.aten.eq.Scalar(expand_as, 1)
#     mul_5: "f32[1, 5, 256]" = torch.ops.aten.mul.Tensor(arg578_1, eq_2);  arg578_1 = eq_2 = None
#     add_3: "f32[1, 5, 256]" = torch.ops.aten.add.Tensor(add_2, mul_5);  add_2 = mul_5 = None
#     eq_3: "b8[1, 5, 256]" = torch.ops.aten.eq.Scalar(expand_as, 2)
#     mul_6: "f32[1, 5, 256]" = torch.ops.aten.mul.Tensor(arg579_1, eq_3);  arg579_1 = eq_3 = None
#     add_4: "f32[1, 5, 256]" = torch.ops.aten.add.Tensor(add_3, mul_6);  add_3 = mul_6 = None
#     eq_4: "b8[1, 5, 256]" = torch.ops.aten.eq.Scalar(expand_as, 3);  expand_as = None
#     mul_7: "f32[1, 5, 256]" = torch.ops.aten.mul.Tensor(arg580_1, eq_4);  arg580_1 = eq_4 = None
#     add_5: "f32[1, 5, 256]" = torch.ops.aten.add.Tensor(add_4, mul_7);  add_4 = mul_7 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#     conv2d: "f32[1, 4, 128, 128]" = torch.ops.aten.conv2d.default(arg719_1, arg582_1, arg583_1, [2, 2]);  arg719_1 = arg582_1 = arg583_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:39 in forward, code: u = x.mean(1, keepdim=True)
#     mean: "f32[1, 1, 128, 128]" = torch.ops.aten.mean.dim(conv2d, [1], True)
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:40 in forward, code: s = (x - u).pow(2).mean(1, keepdim=True)
#     sub_1: "f32[1, 4, 128, 128]" = torch.ops.aten.sub.Tensor(conv2d, mean)
#     pow_1: "f32[1, 4, 128, 128]" = torch.ops.aten.pow.Tensor_Scalar(sub_1, 2);  sub_1 = None
#     mean_1: "f32[1, 1, 128, 128]" = torch.ops.aten.mean.dim(pow_1, [1], True);  pow_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:41 in forward, code: x = (x - u) / torch.sqrt(s + self.eps)
#     sub_2: "f32[1, 4, 128, 128]" = torch.ops.aten.sub.Tensor(conv2d, mean);  conv2d = mean = None
#     add_6: "f32[1, 1, 128, 128]" = torch.ops.aten.add.Tensor(mean_1, 1e-06);  mean_1 = None
#     sqrt: "f32[1, 1, 128, 128]" = torch.ops.aten.sqrt.default(add_6);  add_6 = None
#     div_1: "f32[1, 4, 128, 128]" = torch.ops.aten.div.Tensor(sub_2, sqrt);  sub_2 = sqrt = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:42 in forward, code: x = self.weight[:, None, None] * x + self.bias[:, None, None]
#     unsqueeze_1: "f32[4, 1]" = torch.ops.aten.unsqueeze.default(arg584_1, 1);  arg584_1 = None
#     unsqueeze_2: "f32[4, 1, 1]" = torch.ops.aten.unsqueeze.default(unsqueeze_1, 2);  unsqueeze_1 = None
#     mul_8: "f32[1, 4, 128, 128]" = torch.ops.aten.mul.Tensor(unsqueeze_2, div_1);  unsqueeze_2 = div_1 = None
#     unsqueeze_3: "f32[4, 1]" = torch.ops.aten.unsqueeze.default(arg585_1, 1);  arg585_1 = None
#     unsqueeze_4: "f32[4, 1, 1]" = torch.ops.aten.unsqueeze.default(unsqueeze_3, 2);  unsqueeze_3 = None
#     add_7: "f32[1, 4, 128, 128]" = torch.ops.aten.add.Tensor(mul_8, unsqueeze_4);  mul_8 = unsqueeze_4 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\activation.py:816 in forward, code: return F.gelu(input, approximate=self.approximate)
#     gelu: "f32[1, 4, 128, 128]" = torch.ops.aten.gelu.default(add_7);  add_7 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#     conv2d_1: "f32[1, 16, 64, 64]" = torch.ops.aten.conv2d.default(gelu, arg586_1, arg587_1, [2, 2]);  gelu = arg586_1 = arg587_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:39 in forward, code: u = x.mean(1, keepdim=True)
#     mean_2: "f32[1, 1, 64, 64]" = torch.ops.aten.mean.dim(conv2d_1, [1], True)
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:40 in forward, code: s = (x - u).pow(2).mean(1, keepdim=True)
#     sub_3: "f32[1, 16, 64, 64]" = torch.ops.aten.sub.Tensor(conv2d_1, mean_2)
#     pow_2: "f32[1, 16, 64, 64]" = torch.ops.aten.pow.Tensor_Scalar(sub_3, 2);  sub_3 = None
#     mean_3: "f32[1, 1, 64, 64]" = torch.ops.aten.mean.dim(pow_2, [1], True);  pow_2 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:41 in forward, code: x = (x - u) / torch.sqrt(s + self.eps)
#     sub_4: "f32[1, 16, 64, 64]" = torch.ops.aten.sub.Tensor(conv2d_1, mean_2);  conv2d_1 = mean_2 = None
#     add_8: "f32[1, 1, 64, 64]" = torch.ops.aten.add.Tensor(mean_3, 1e-06);  mean_3 = None
#     sqrt_1: "f32[1, 1, 64, 64]" = torch.ops.aten.sqrt.default(add_8);  add_8 = None
#     div_2: "f32[1, 16, 64, 64]" = torch.ops.aten.div.Tensor(sub_4, sqrt_1);  sub_4 = sqrt_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\common.py:42 in forward, code: x = self.weight[:, None, None] * x + self.bias[:, None, None]
#     unsqueeze_5: "f32[16, 1]" = torch.ops.aten.unsqueeze.default(arg588_1, 1);  arg588_1 = None
#     unsqueeze_6: "f32[16, 1, 1]" = torch.ops.aten.unsqueeze.default(unsqueeze_5, 2);  unsqueeze_5 = None
#     mul_9: "f32[1, 16, 64, 64]" = torch.ops.aten.mul.Tensor(unsqueeze_6, div_2);  unsqueeze_6 = div_2 = None
#     unsqueeze_7: "f32[16, 1]" = torch.ops.aten.unsqueeze.default(arg589_1, 1);  arg589_1 = None
#     unsqueeze_8: "f32[16, 1, 1]" = torch.ops.aten.unsqueeze.default(unsqueeze_7, 2);  unsqueeze_7 = None
#     add_9: "f32[1, 16, 64, 64]" = torch.ops.aten.add.Tensor(mul_9, unsqueeze_8);  mul_9 = unsqueeze_8 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\activation.py:816 in forward, code: return F.gelu(input, approximate=self.approximate)
#     gelu_1: "f32[1, 16, 64, 64]" = torch.ops.aten.gelu.default(add_9);  add_9 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#     conv2d_2: "f32[1, 256, 64, 64]" = torch.ops.aten.conv2d.default(gelu_1, arg590_1, arg591_1);  gelu_1 = arg590_1 = arg591_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py:118 in forward, code: dense_embedding = self._embed_masks(mask_input, has_mask_input)
#     mul_10: "f32[1, 256, 64, 64]" = torch.ops.aten.mul.Tensor(arg720_1, conv2d_2);  conv2d_2 = None
#     rsub: "f32[1]" = torch.ops.aten.rsub.Scalar(arg720_1, 1);  arg720_1 = None
#     reshape: "f32[1, 256, 1, 1]" = torch.ops.aten.reshape.default(arg592_1, [1, -1, 1, 1]);  arg592_1 = None
#     mul_11: "f32[1, 256, 1, 1]" = torch.ops.aten.mul.Tensor(rsub, reshape);  rsub = reshape = None
#     add_10: "f32[1, 256, 64, 64]" = torch.ops.aten.add.Tensor(mul_10, mul_11);  mul_10 = mul_11 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:198 in forward, code: grid = torch.ones((h, w), device=device, dtype=torch.float32)
#     ones: "f32[64, 64]" = torch.ops.aten.ones.default([64, 64], dtype = torch.float32, device = device(type='cpu'), pin_memory = False)
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:199 in forward, code: y_embed = grid.cumsum(dim=0) - 0.5
#     cumsum: "f32[64, 64]" = torch.ops.aten.cumsum.default(ones, 0)
#     sub_5: "f32[64, 64]" = torch.ops.aten.sub.Tensor(cumsum, 0.5);  cumsum = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:200 in forward, code: x_embed = grid.cumsum(dim=1) - 0.5
#     cumsum_1: "f32[64, 64]" = torch.ops.aten.cumsum.default(ones, 1);  ones = None
#     sub_6: "f32[64, 64]" = torch.ops.aten.sub.Tensor(cumsum_1, 0.5);  cumsum_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:201 in forward, code: y_embed = y_embed / h
#     div_3: "f32[64, 64]" = torch.ops.aten.div.Tensor(sub_5, 64);  sub_5 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:202 in forward, code: x_embed = x_embed / w
#     div_4: "f32[64, 64]" = torch.ops.aten.div.Tensor(sub_6, 64);  sub_6 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:204 in forward, code: pe = self._pe_encoding(torch.stack([x_embed, y_embed], dim=-1))
#     stack: "f32[64, 64, 2]" = torch.ops.aten.stack.default([div_4, div_3], -1);  div_4 = div_3 = None
#     mul_12: "f32[64, 64, 2]" = torch.ops.aten.mul.Tensor(stack, 2);  stack = None
#     sub_7: "f32[64, 64, 2]" = torch.ops.aten.sub.Tensor(mul_12, 1);  mul_12 = None
#     matmul_1: "f32[64, 64, 128]" = torch.ops.aten.matmul.default(sub_7, arg715_1);  sub_7 = arg715_1 = None
#     mul_13: "f32[64, 64, 128]" = torch.ops.aten.mul.Tensor(matmul_1, 6.283185307179586);  matmul_1 = None
#     sin_1: "f32[64, 64, 128]" = torch.ops.aten.sin.default(mul_13)
#     cos_1: "f32[64, 64, 128]" = torch.ops.aten.cos.default(mul_13);  mul_13 = None
#     cat_1: "f32[64, 64, 256]" = torch.ops.aten.cat.default([sin_1, cos_1], -1);  sin_1 = cos_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\prompt_encoder.py:205 in forward, code: return pe.permute(2, 0, 1)  # C x H x W
#     permute: "f32[256, 64, 64]" = torch.ops.aten.permute.default(cat_1, [2, 0, 1]);  cat_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py:122 in forward, code: image_pe=self.model.prompt_encoder.get_dense_pe(),
#     unsqueeze_9: "f32[1, 256, 64, 64]" = torch.ops.aten.unsqueeze.default(permute, 0);  permute = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py:120 in forward, code: masks, scores = self.model.mask_decoder.predict_masks(
#     cat_2: "f32[5, 256]" = torch.ops.aten.cat.default([arg675_1, arg676_1]);  arg675_1 = arg676_1 = None
#     unsqueeze_10: "f32[1, 5, 256]" = torch.ops.aten.unsqueeze.default(cat_2, 0);  cat_2 = None
#     expand: "f32[1, 5, 256]" = torch.ops.aten.expand.default(unsqueeze_10, [1, -1, -1]);  unsqueeze_10 = None
#     cat_3: "f32[1, 10, 256]" = torch.ops.aten.cat.default([expand, add_5], 1);  expand = add_5 = None
#     repeat_interleave: "f32[1, 256, 64, 64]" = torch.ops.aten.repeat_interleave.self_int(arg716_1, 1, 0);  arg716_1 = None
#     add_11: "f32[1, 256, 64, 64]" = torch.ops.aten.add.Tensor(repeat_interleave, add_10);  repeat_interleave = add_10 = None
#     repeat_interleave_1: "f32[1, 256, 64, 64]" = torch.ops.aten.repeat_interleave.self_int(unsqueeze_9, 1, 0);  unsqueeze_9 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:83 in forward, code: image_embedding = image_embedding.flatten(2).permute(0, 2, 1)
#     flatten: "f32[1, 256, 4096]" = torch.ops.aten.flatten.using_ints(add_11, 2);  add_11 = None
#     permute_1: "f32[1, 4096, 256]" = torch.ops.aten.permute.default(flatten, [0, 2, 1]);  flatten = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:84 in forward, code: image_pe = image_pe.flatten(2).permute(0, 2, 1)
#     flatten_1: "f32[1, 256, 4096]" = torch.ops.aten.flatten.using_ints(repeat_interleave_1, 2);  repeat_interleave_1 = None
#     permute_2: "f32[1, 4096, 256]" = torch.ops.aten.permute.default(flatten_1, [0, 2, 1]);  flatten_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear: "f32[1, 10, 256]" = torch.ops.aten.linear.default(cat_3, arg593_1, arg594_1);  arg593_1 = arg594_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_1: "f32[1, 10, 256]" = torch.ops.aten.linear.default(cat_3, arg595_1, arg596_1);  arg595_1 = arg596_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_2: "f32[1, 10, 256]" = torch.ops.aten.linear.default(cat_3, arg597_1, arg598_1);  arg597_1 = arg598_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:225 in forward, code: q = self._separate_heads(q, self.num_heads)
#     reshape_1: "f32[1, 10, 8, 32]" = torch.ops.aten.reshape.default(linear, [1, 10, 8, 32]);  linear = None
#     transpose: "f32[1, 8, 10, 32]" = torch.ops.aten.transpose.int(reshape_1, 1, 2);  reshape_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:226 in forward, code: k = self._separate_heads(k, self.num_heads)
#     reshape_2: "f32[1, 10, 8, 32]" = torch.ops.aten.reshape.default(linear_1, [1, 10, 8, 32]);  linear_1 = None
#     transpose_1: "f32[1, 8, 10, 32]" = torch.ops.aten.transpose.int(reshape_2, 1, 2);  reshape_2 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:227 in forward, code: v = self._separate_heads(v, self.num_heads)
#     reshape_3: "f32[1, 10, 8, 32]" = torch.ops.aten.reshape.default(linear_2, [1, 10, 8, 32]);  linear_2 = None
#     transpose_2: "f32[1, 8, 10, 32]" = torch.ops.aten.transpose.int(reshape_3, 1, 2);  reshape_3 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:231 in forward, code: attn = q @ k.permute(0, 1, 3, 2)  # B x N_heads x N_tokens x N_tokens
#     permute_3: "f32[1, 8, 32, 10]" = torch.ops.aten.permute.default(transpose_1, [0, 1, 3, 2]);  transpose_1 = None
#     matmul_2: "f32[1, 8, 10, 10]" = torch.ops.aten.matmul.default(transpose, permute_3);  transpose = permute_3 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:232 in forward, code: attn = attn / math.sqrt(c_per_head)
#     div_5: "f32[1, 8, 10, 10]" = torch.ops.aten.div.Tensor(matmul_2, 5.656854249492381);  matmul_2 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:233 in forward, code: attn = torch.softmax(attn, dim=-1)
#     softmax: "f32[1, 8, 10, 10]" = torch.ops.aten.softmax.int(div_5, -1);  div_5 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:236 in forward, code: out = attn @ v
#     matmul_3: "f32[1, 8, 10, 32]" = torch.ops.aten.matmul.default(softmax, transpose_2);  softmax = transpose_2 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:237 in forward, code: out = self._recombine_heads(out)
#     transpose_3: "f32[1, 10, 8, 32]" = torch.ops.aten.transpose.int(matmul_3, 1, 2);  matmul_3 = None
#     reshape_4: "f32[1, 10, 256]" = torch.ops.aten.reshape.default(transpose_3, [1, 10, 256]);  transpose_3 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_3: "f32[1, 10, 256]" = torch.ops.aten.linear.default(reshape_4, arg599_1, arg600_1);  reshape_4 = arg599_1 = arg600_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\normalization.py:229 in forward, code: return F.layer_norm(
#     layer_norm: "f32[1, 10, 256]" = torch.ops.aten.layer_norm.default(linear_3, [256], arg601_1, arg602_1);  linear_3 = arg601_1 = arg602_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:164 in forward, code: q = queries + query_pe
#     add_12: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm, cat_3)
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:165 in forward, code: k = keys + key_pe
#     add_13: "f32[1, 4096, 256]" = torch.ops.aten.add.Tensor(permute_1, permute_2)
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_4: "f32[1, 10, 128]" = torch.ops.aten.linear.default(add_12, arg603_1, arg604_1);  add_12 = arg603_1 = arg604_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_5: "f32[1, 4096, 128]" = torch.ops.aten.linear.default(add_13, arg605_1, arg606_1);  add_13 = arg605_1 = arg606_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_6: "f32[1, 4096, 128]" = torch.ops.aten.linear.default(permute_1, arg607_1, arg608_1);  arg607_1 = arg608_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:225 in forward, code: q = self._separate_heads(q, self.num_heads)
#     reshape_5: "f32[1, 10, 8, 16]" = torch.ops.aten.reshape.default(linear_4, [1, 10, 8, 16]);  linear_4 = None
#     transpose_4: "f32[1, 8, 10, 16]" = torch.ops.aten.transpose.int(reshape_5, 1, 2);  reshape_5 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:226 in forward, code: k = self._separate_heads(k, self.num_heads)
#     reshape_6: "f32[1, 4096, 8, 16]" = torch.ops.aten.reshape.default(linear_5, [1, 4096, 8, 16]);  linear_5 = None
#     transpose_5: "f32[1, 8, 4096, 16]" = torch.ops.aten.transpose.int(reshape_6, 1, 2);  reshape_6 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:227 in forward, code: v = self._separate_heads(v, self.num_heads)
#     reshape_7: "f32[1, 4096, 8, 16]" = torch.ops.aten.reshape.default(linear_6, [1, 4096, 8, 16]);  linear_6 = None
#     transpose_6: "f32[1, 8, 4096, 16]" = torch.ops.aten.transpose.int(reshape_7, 1, 2);  reshape_7 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:231 in forward, code: attn = q @ k.permute(0, 1, 3, 2)  # B x N_heads x N_tokens x N_tokens
#     permute_4: "f32[1, 8, 16, 4096]" = torch.ops.aten.permute.default(transpose_5, [0, 1, 3, 2]);  transpose_5 = None
#     matmul_4: "f32[1, 8, 10, 4096]" = torch.ops.aten.matmul.default(transpose_4, permute_4);  transpose_4 = permute_4 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:232 in forward, code: attn = attn / math.sqrt(c_per_head)
#     div_6: "f32[1, 8, 10, 4096]" = torch.ops.aten.div.Tensor(matmul_4, 4.0);  matmul_4 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:233 in forward, code: attn = torch.softmax(attn, dim=-1)
#     softmax_1: "f32[1, 8, 10, 4096]" = torch.ops.aten.softmax.int(div_6, -1);  div_6 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:236 in forward, code: out = attn @ v
#     matmul_5: "f32[1, 8, 10, 16]" = torch.ops.aten.matmul.default(softmax_1, transpose_6);  softmax_1 = transpose_6 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:237 in forward, code: out = self._recombine_heads(out)
#     transpose_7: "f32[1, 10, 8, 16]" = torch.ops.aten.transpose.int(matmul_5, 1, 2);  matmul_5 = None
#     reshape_8: "f32[1, 10, 128]" = torch.ops.aten.reshape.default(transpose_7, [1, 10, 128]);  transpose_7 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_7: "f32[1, 10, 256]" = torch.ops.aten.linear.default(reshape_8, arg609_1, arg610_1);  reshape_8 = arg609_1 = arg610_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:167 in forward, code: queries = queries + attn_out
#     add_14: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm, linear_7);  layer_norm = linear_7 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\normalization.py:229 in forward, code: return F.layer_norm(
#     layer_norm_1: "f32[1, 10, 256]" = torch.ops.aten.layer_norm.default(add_14, [256], arg611_1, arg612_1);  add_14 = arg611_1 = arg612_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_8: "f32[1, 10, 2048]" = torch.ops.aten.linear.default(layer_norm_1, arg613_1, arg614_1);  arg613_1 = arg614_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#     relu: "f32[1, 10, 2048]" = torch.ops.aten.relu.default(linear_8);  linear_8 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_9: "f32[1, 10, 256]" = torch.ops.aten.linear.default(relu, arg615_1, arg616_1);  relu = arg615_1 = arg616_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:172 in forward, code: queries = queries + mlp_out
#     add_15: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm_1, linear_9);  layer_norm_1 = linear_9 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\normalization.py:229 in forward, code: return F.layer_norm(
#     layer_norm_2: "f32[1, 10, 256]" = torch.ops.aten.layer_norm.default(add_15, [256], arg617_1, arg618_1);  add_15 = arg617_1 = arg618_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:176 in forward, code: q = queries + query_pe
#     add_16: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm_2, cat_3)
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:177 in forward, code: k = keys + key_pe
#     add_17: "f32[1, 4096, 256]" = torch.ops.aten.add.Tensor(permute_1, permute_2)
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_10: "f32[1, 4096, 128]" = torch.ops.aten.linear.default(add_17, arg621_1, arg622_1);  add_17 = arg621_1 = arg622_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_11: "f32[1, 10, 128]" = torch.ops.aten.linear.default(add_16, arg623_1, arg624_1);  add_16 = arg623_1 = arg624_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_12: "f32[1, 10, 128]" = torch.ops.aten.linear.default(layer_norm_2, arg625_1, arg626_1);  arg625_1 = arg626_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:225 in forward, code: q = self._separate_heads(q, self.num_heads)
#     reshape_9: "f32[1, 4096, 8, 16]" = torch.ops.aten.reshape.default(linear_10, [1, 4096, 8, 16]);  linear_10 = None
#     transpose_8: "f32[1, 8, 4096, 16]" = torch.ops.aten.transpose.int(reshape_9, 1, 2);  reshape_9 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:226 in forward, code: k = self._separate_heads(k, self.num_heads)
#     reshape_10: "f32[1, 10, 8, 16]" = torch.ops.aten.reshape.default(linear_11, [1, 10, 8, 16]);  linear_11 = None
#     transpose_9: "f32[1, 8, 10, 16]" = torch.ops.aten.transpose.int(reshape_10, 1, 2);  reshape_10 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:227 in forward, code: v = self._separate_heads(v, self.num_heads)
#     reshape_11: "f32[1, 10, 8, 16]" = torch.ops.aten.reshape.default(linear_12, [1, 10, 8, 16]);  linear_12 = None
#     transpose_10: "f32[1, 8, 10, 16]" = torch.ops.aten.transpose.int(reshape_11, 1, 2);  reshape_11 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:231 in forward, code: attn = q @ k.permute(0, 1, 3, 2)  # B x N_heads x N_tokens x N_tokens
#     permute_5: "f32[1, 8, 16, 10]" = torch.ops.aten.permute.default(transpose_9, [0, 1, 3, 2]);  transpose_9 = None
#     matmul_6: "f32[1, 8, 4096, 10]" = torch.ops.aten.matmul.default(transpose_8, permute_5);  transpose_8 = permute_5 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:232 in forward, code: attn = attn / math.sqrt(c_per_head)
#     div_7: "f32[1, 8, 4096, 10]" = torch.ops.aten.div.Tensor(matmul_6, 4.0);  matmul_6 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:233 in forward, code: attn = torch.softmax(attn, dim=-1)
#     softmax_2: "f32[1, 8, 4096, 10]" = torch.ops.aten.softmax.int(div_7, -1);  div_7 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:236 in forward, code: out = attn @ v
#     matmul_7: "f32[1, 8, 4096, 16]" = torch.ops.aten.matmul.default(softmax_2, transpose_10);  softmax_2 = transpose_10 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:237 in forward, code: out = self._recombine_heads(out)
#     transpose_11: "f32[1, 4096, 8, 16]" = torch.ops.aten.transpose.int(matmul_7, 1, 2);  matmul_7 = None
#     reshape_12: "f32[1, 4096, 128]" = torch.ops.aten.reshape.default(transpose_11, [1, 4096, 128]);  transpose_11 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_13: "f32[1, 4096, 256]" = torch.ops.aten.linear.default(reshape_12, arg627_1, arg628_1);  reshape_12 = arg627_1 = arg628_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:179 in forward, code: keys = keys + attn_out
#     add_18: "f32[1, 4096, 256]" = torch.ops.aten.add.Tensor(permute_1, linear_13);  permute_1 = linear_13 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\normalization.py:229 in forward, code: return F.layer_norm(
#     layer_norm_3: "f32[1, 4096, 256]" = torch.ops.aten.layer_norm.default(add_18, [256], arg619_1, arg620_1);  add_18 = arg619_1 = arg620_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:158 in forward, code: q = queries + query_pe
#     add_19: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm_2, cat_3)
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_14: "f32[1, 10, 256]" = torch.ops.aten.linear.default(add_19, arg629_1, arg630_1);  arg629_1 = arg630_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_15: "f32[1, 10, 256]" = torch.ops.aten.linear.default(add_19, arg631_1, arg632_1);  add_19 = arg631_1 = arg632_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_16: "f32[1, 10, 256]" = torch.ops.aten.linear.default(layer_norm_2, arg633_1, arg634_1);  arg633_1 = arg634_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:225 in forward, code: q = self._separate_heads(q, self.num_heads)
#     reshape_13: "f32[1, 10, 8, 32]" = torch.ops.aten.reshape.default(linear_14, [1, 10, 8, 32]);  linear_14 = None
#     transpose_12: "f32[1, 8, 10, 32]" = torch.ops.aten.transpose.int(reshape_13, 1, 2);  reshape_13 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:226 in forward, code: k = self._separate_heads(k, self.num_heads)
#     reshape_14: "f32[1, 10, 8, 32]" = torch.ops.aten.reshape.default(linear_15, [1, 10, 8, 32]);  linear_15 = None
#     transpose_13: "f32[1, 8, 10, 32]" = torch.ops.aten.transpose.int(reshape_14, 1, 2);  reshape_14 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:227 in forward, code: v = self._separate_heads(v, self.num_heads)
#     reshape_15: "f32[1, 10, 8, 32]" = torch.ops.aten.reshape.default(linear_16, [1, 10, 8, 32]);  linear_16 = None
#     transpose_14: "f32[1, 8, 10, 32]" = torch.ops.aten.transpose.int(reshape_15, 1, 2);  reshape_15 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:231 in forward, code: attn = q @ k.permute(0, 1, 3, 2)  # B x N_heads x N_tokens x N_tokens
#     permute_6: "f32[1, 8, 32, 10]" = torch.ops.aten.permute.default(transpose_13, [0, 1, 3, 2]);  transpose_13 = None
#     matmul_8: "f32[1, 8, 10, 10]" = torch.ops.aten.matmul.default(transpose_12, permute_6);  transpose_12 = permute_6 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:232 in forward, code: attn = attn / math.sqrt(c_per_head)
#     div_8: "f32[1, 8, 10, 10]" = torch.ops.aten.div.Tensor(matmul_8, 5.656854249492381);  matmul_8 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:233 in forward, code: attn = torch.softmax(attn, dim=-1)
#     softmax_3: "f32[1, 8, 10, 10]" = torch.ops.aten.softmax.int(div_8, -1);  div_8 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:236 in forward, code: out = attn @ v
#     matmul_9: "f32[1, 8, 10, 32]" = torch.ops.aten.matmul.default(softmax_3, transpose_14);  softmax_3 = transpose_14 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:237 in forward, code: out = self._recombine_heads(out)
#     transpose_15: "f32[1, 10, 8, 32]" = torch.ops.aten.transpose.int(matmul_9, 1, 2);  matmul_9 = None
#     reshape_16: "f32[1, 10, 256]" = torch.ops.aten.reshape.default(transpose_15, [1, 10, 256]);  transpose_15 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_17: "f32[1, 10, 256]" = torch.ops.aten.linear.default(reshape_16, arg635_1, arg636_1);  reshape_16 = arg635_1 = arg636_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:160 in forward, code: queries = queries + attn_out
#     add_20: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm_2, linear_17);  layer_norm_2 = linear_17 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\normalization.py:229 in forward, code: return F.layer_norm(
#     layer_norm_4: "f32[1, 10, 256]" = torch.ops.aten.layer_norm.default(add_20, [256], arg637_1, arg638_1);  add_20 = arg637_1 = arg638_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:164 in forward, code: q = queries + query_pe
#     add_21: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm_4, cat_3)
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:165 in forward, code: k = keys + key_pe
#     add_22: "f32[1, 4096, 256]" = torch.ops.aten.add.Tensor(layer_norm_3, permute_2)
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_18: "f32[1, 10, 128]" = torch.ops.aten.linear.default(add_21, arg639_1, arg640_1);  add_21 = arg639_1 = arg640_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_19: "f32[1, 4096, 128]" = torch.ops.aten.linear.default(add_22, arg641_1, arg642_1);  add_22 = arg641_1 = arg642_1 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_20: "f32[1, 4096, 128]" = torch.ops.aten.linear.default(layer_norm_3, arg643_1, arg644_1);  arg643_1 = arg644_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:225 in forward, code: q = self._separate_heads(q, self.num_heads)
#     reshape_17: "f32[1, 10, 8, 16]" = torch.ops.aten.reshape.default(linear_18, [1, 10, 8, 16]);  linear_18 = None
#     transpose_16: "f32[1, 8, 10, 16]" = torch.ops.aten.transpose.int(reshape_17, 1, 2);  reshape_17 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:226 in forward, code: k = self._separate_heads(k, self.num_heads)
#     reshape_18: "f32[1, 4096, 8, 16]" = torch.ops.aten.reshape.default(linear_19, [1, 4096, 8, 16]);  linear_19 = None
#     transpose_17: "f32[1, 8, 4096, 16]" = torch.ops.aten.transpose.int(reshape_18, 1, 2);  reshape_18 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:227 in forward, code: v = self._separate_heads(v, self.num_heads)
#     reshape_19: "f32[1, 4096, 8, 16]" = torch.ops.aten.reshape.default(linear_20, [1, 4096, 8, 16]);  linear_20 = None
#     transpose_18: "f32[1, 8, 4096, 16]" = torch.ops.aten.transpose.int(reshape_19, 1, 2);  reshape_19 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:231 in forward, code: attn = q @ k.permute(0, 1, 3, 2)  # B x N_heads x N_tokens x N_tokens
#     permute_7: "f32[1, 8, 16, 4096]" = torch.ops.aten.permute.default(transpose_17, [0, 1, 3, 2]);  transpose_17 = None
#     matmul_10: "f32[1, 8, 10, 4096]" = torch.ops.aten.matmul.default(transpose_16, permute_7);  transpose_16 = permute_7 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:232 in forward, code: attn = attn / math.sqrt(c_per_head)
#     div_9: "f32[1, 8, 10, 4096]" = torch.ops.aten.div.Tensor(matmul_10, 4.0);  matmul_10 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:233 in forward, code: attn = torch.softmax(attn, dim=-1)
#     softmax_4: "f32[1, 8, 10, 4096]" = torch.ops.aten.softmax.int(div_9, -1);  div_9 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:236 in forward, code: out = attn @ v
#     matmul_11: "f32[1, 8, 10, 16]" = torch.ops.aten.matmul.default(softmax_4, transpose_18);  softmax_4 = transpose_18 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:237 in forward, code: out = self._recombine_heads(out)
#     transpose_19: "f32[1, 10, 8, 16]" = torch.ops.aten.transpose.int(matmul_11, 1, 2);  matmul_11 = None
#     reshape_20: "f32[1, 10, 128]" = torch.ops.aten.reshape.default(transpose_19, [1, 10, 128]);  transpose_19 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#     linear_21: "f32[1, 10, 256]" = torch.ops.aten.linear.default(reshape_20, arg645_1, arg646_1);  reshape_20 = arg645_1 = arg646_1 = None
#
#      # File: D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\modeling\transformer.py:167 in forward, code: queries = queries + attn_out
#     add_23: "f32[1, 10, 256]" = torch.ops.aten.add.Tensor(layer_norm_4, linear_21);  layer_norm_4 = linear_21 = None
#
#      # File: d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\normalization.py:229 in forward, code: return F.layer_norm(
#     layer_norm_5: "f32[1, 10, 256]" = torch.ops.aten.layer_norm.default(add_23, [256], arg647_1, arg648_1);  add_23 = arg647_1 = arg648_1 = None
#
# ...
#     838 _autowrap_check(
#     839     patcher,  # type: ignore[has-type]
#     840     getattr(getattr(mod, "forward", mod), "__globals__", {}),
#     841     self._autowrap_function_ids,
#     842 )
# --> 843 return self.call_module(mod, forward, args, kwargs)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\proxy_tensor.py:1997, in _ModuleStackTracer.call_module(self, m, forward, args, kwargs)
#    1996 try:
# -> 1997     return Tracer.call_module(self, m, forward, args, kwargs)
#    1998 except _ModuleNotInstalledAsSubmoduleError:
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\_symbolic_trace.py:560, in Tracer.call_module(self, m, forward, args, kwargs)
#     559 if not self.is_leaf_module(m, module_qualified_name):
# --> 560     ret_val = forward(*args, **kwargs)
#     561 else:
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\_symbolic_trace.py:836, in Tracer.trace.<locals>.module_call_wrapper.<locals>.forward(*args, **kwargs)
#     835 def forward(*args, **kwargs):
# --> 836     return _orig_module_call(mod, *args, **kwargs)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     119 with ctx_factory():
# --> 120     return func(*args, **kwargs)
#
# File D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py:135, in SamOnnxModel.forward(self, image_embeddings, point_coords, point_labels, mask_input, has_mask_input, orig_im_size)
#     133     masks, scores = self.select_masks(masks, scores, point_coords.shape[1])
# --> 135 upscaled_masks = self.mask_postprocessing(masks, orig_im_size)
#     137 if self.return_extra_metrics:
#
# File D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py:85, in SamOnnxModel.mask_postprocessing(self, masks, orig_im_size)
#      84 prepadded_size = self.resize_longest_image_size(orig_im_size, self.img_size).to(torch.int64)
# ---> 85 masks = masks[..., : prepadded_size[0], : prepadded_size[1]]  # type: ignore
#      87 orig_im_size = orig_im_size.to(torch.int64)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\proxy_tensor.py:1409, in TorchFunctionMetadataMode.__torch_function__(self, func, types, args, kwargs)
#    1408 self.tracer.torch_fn_counts[func] = self.tracer.torch_fn_counts.get(func, 0) + 1
# -> 1409 return func(*args, **kwargs)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\proxy_tensor.py:1479, in PreDispatchTorchFunctionMode.__torch_function__(self, func, types, args, kwargs)
#    1478     return res
# -> 1479 return func(*args, **kwargs)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\_export\non_strict_utils.py:1066, in _NonStrictTorchFunctionHandler.__torch_function__(self, func, types, args, kwargs)
#    1065 try:
# -> 1066     return func(*args, **kwargs)
#    1067 except GuardOnDataDependentSymNode as e:
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\sym_node.py:518, in SymNode.guard_int(self, file, line)
#     515 def guard_int(self, file, line):
#     516     # TODO: use the file/line for some useful diagnostic on why a
#     517     # guard occurred
# --> 518     r = self.evaluate()
#     519     try:
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\sym_node.py:512, in SymNode.evaluate(self, size_oblivious)
#     511 def evaluate(self, size_oblivious=False):
# --> 512     return self.shape_env.evaluate_sym_node(self, size_oblivious)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:7233, in ShapeEnv.evaluate_sym_node(self, sym_node, size_oblivious, fallback_value)
#    7232 self._expr_sym_node_id = id(sym_node)
# -> 7233 return self.evaluate_expr(
#    7234     sym_node.expr,
#    7235     sym_node.hint,
#    7236     sym_node.fx_node,
#    7237     size_oblivious,
#    7238     fallback_value=fallback_value,
#    7239 )
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:7333, in ShapeEnv.evaluate_expr(self, orig_expr, hint, fx_node, size_oblivious, fallback_value, forcing_spec)
#    7332 suppress_guards_tls = ShapeEnv._suppress_guards_tls()
# -> 7333 return self._inner_evaluate_expr(
#    7334     orig_expr,
#    7335     hint,
#    7336     fx_node,
#    7337     size_oblivious,
#    7338     forcing_spec,
#    7339     suppress_guards_tls,
#    7340     fallback_value,
#    7341 )
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\recording.py:272, in record_shapeenv_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     266 if not shape_env.should_record_events or shape_env.is_recording:  # type: ignore[has-type]
#     267     # If ShapeEnv is already recording an event, call the wrapped
#     268     # function directly.
#     269     #
#     270     # NB: here, we skip the check of whether all ShapeEnv instances
#     271     # are equal, in favor of a faster dispatch.
# --> 272     return retlog(fn(*args, **kwargs))
#     274 # Retrieve an instance of ShapeEnv.
#     275 # Assumption: the collection of args and kwargs may not reference
#     276 # different ShapeEnv instances.
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:7356, in ShapeEnv._inner_evaluate_expr(self, orig_expr, hint, fx_node, size_oblivious, forcing_spec, _suppress_guards_tls, fallback_value)
#    7355 try:
# -> 7356     return self._evaluate_expr(
#    7357         orig_expr,
#    7358         hint,
#    7359         fx_node,
#    7360         size_oblivious,
#    7361         fallback_value,
#    7362         forcing_spec=forcing_spec,
#    7363     )
#    7364 except Exception as e:
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:7574, in ShapeEnv._evaluate_expr(self, orig_expr, hint, fx_node, size_oblivious, fallback_value, forcing_spec)
#    7573     if not ok:
# -> 7574         raise self._make_data_dependent_error(
#    7575             expr.xreplace(self.var_to_val),
#    7576             expr,
#    7577             expr_sym_node_id=self._expr_sym_node_id,
#    7578         )
#    7579 else:
#
# GuardOnDataDependentSymNode: Could not extract specialized integer from data-dependent expression u0 (unhinted: u0).  (Size-like symbols: none)
#
# Caused by: (_export\non_strict_utils.py:1066 in __torch_function__)
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The following call raised this error:
#   File "D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py", line 85, in mask_postprocessing
#     masks = masks[..., : prepadded_size[0], : prepadded_size[1]]  # type: ignore
#
#
# The error above occurred when calling torch.export.export. If you would like to view some more information about this error, and get a list of all other errors that may occur in your export call, you can replace your `export()` call with `draft_export()`.
#
# The above exception was the direct cause of the following exception:
#
# TorchExportError                          Traceback (most recent call last)
# Cell In[23], line 29
#      27 warnings.filterwarnings("ignore", category=UserWarning)
#      28 with open(onnx_model_path, "wb") as f:
# ---> 29     torch.onnx.export(
#      30         onnx_model,
#      31         tuple(dummy_inputs.values()),
#      32         f,
#      33         export_params=True,
#      34         verbose=False,
#      35         opset_version=13,
#      36         do_constant_folding=True,
#      37         input_names=list(dummy_inputs.keys()),
#      38         output_names=output_names,
#      39         dynamic_axes=dynamic_axes,
#      40     )
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\onnx\__init__.py:296, in export(model, args, f, kwargs, verbose, input_names, output_names, opset_version, dynamo, external_data, dynamic_shapes, custom_translation_table, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, export_params, keep_initializers_as_inputs, dynamic_axes, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining)
#     286     # Prepare legacy export parameters for potential fallback
#     287     legacy_export_kwargs = {
#     288         "training": training,
#     289         "operator_export_type": operator_export_type,
#    (...)    293         "autograd_inlining": autograd_inlining,
#     294     }
# --> 296     return _compat.export_compat(
#     297         model,
#     298         args,
#     299         f,
#     300         kwargs=kwargs,
#     301         export_params=export_params,
#     302         verbose=verbose,
#     303         input_names=input_names,
#     304         output_names=output_names,
#     305         opset_version=opset_version,
#     306         custom_translation_table=custom_translation_table,
#     307         dynamic_axes=dynamic_axes,
#     308         keep_initializers_as_inputs=keep_initializers_as_inputs,
#     309         external_data=external_data,
#     310         dynamic_shapes=dynamic_shapes,
#     311         report=report,
#     312         optimize=optimize,
#     313         verify=verify,
#     314         profile=profile,
#     315         dump_exported_program=dump_exported_program,
#     316         artifacts_dir=artifacts_dir,
#     317         fallback=fallback,
#     318         legacy_export_kwargs=legacy_export_kwargs,
#     319     )
#     320 else:
#     321     import warnings
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\onnx\_internal\exporter\_compat.py:143, in export_compat(model, args, f, kwargs, export_params, verbose, input_names, output_names, opset_version, custom_translation_table, dynamic_axes, dynamic_shapes, keep_initializers_as_inputs, external_data, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, legacy_export_kwargs)
#     141             registry.register_op(torch_op, op, is_complex=False)
#     142 try:
# --> 143     onnx_program = _core.export(
#     144         model,
#     145         args,
#     146         kwargs,
#     147         registry=registry,
#     148         dynamic_shapes=dynamic_shapes_with_export_dim,
#     149         input_names=input_names,
#     150         output_names=output_names,
#     151         profile=profile,
#     152         report=report,
#     153         verify=verify,
#     154         dump_exported_program=dump_exported_program,
#     155         artifacts_dir=artifacts_dir,
#     156         verbose=verbose,
#     157     )
#     159 except Exception as e:
#     160     if fallback:
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\onnx\_internal\exporter\_flags.py:23, in set_onnx_exporting_flag.<locals>.wrapper(*args, **kwargs)
#      21 _is_onnx_exporting = True
#      22 try:
# ---> 23     return func(*args, **kwargs)
#      24 finally:
#      25     # Ensure it resets even if an exception occurs
#      26     _is_onnx_exporting = False
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\torch\onnx\_internal\exporter\_core.py:1385, in export(model, args, kwargs, registry, dynamic_shapes, input_names, output_names, report, verify, profile, dump_exported_program, artifacts_dir, verbose)
#    1379         assert first_error is not None
#    1381         # NOTE: We only throw the torch.export (first) exception because we want to
#    1382         # focus on the torch.export.export error. Errors from other strategies like
#    1383         # torch.jit.trace is due to the fallback and can be confusing to users.
#    1384         # We save all errors in the error report.
# -> 1385         raise _errors.TorchExportError(
#    1386             _STEP_ONE_ERROR_MESSAGE
#    1387             + (
#    1388                 f"\nError report has been saved to '{report_path}'."
#    1389                 if report
#    1390                 else ""
#    1391             )
#    1392             + _summarize_exception_stack(first_error)
#    1393         ) from first_error
#    1395 assert program is not None
#    1397 if dump_exported_program:
#
# TorchExportError: Failed to export the model with torch.export. This is step 1/3 of exporting the model to ONNX. Next steps:
# - Modify the model code for `torch.export.export` to succeed. Refer to https://pytorch.org/docs/stable/generated/exportdb/index.html for more information.
# - Debug `torch.export.export` and submit a PR to PyTorch.
# - Create an issue in the PyTorch GitHub repository against the *torch.export* component and attach the full error stack as well as reproduction scripts.
#
# ## Exception summary
#
# <class 'torch.fx.experimental.symbolic_shapes.GuardOnDataDependentSymNode'>: Could not extract specialized integer from data-dependent expression u0 (unhinted: u0).  (Size-like symbols: none)
#
# Caused by: (_export\non_strict_utils.py:1066 in __torch_function__)
# For more information, run with TORCH_LOGS="dynamic"
# For extended logs when we create symbols, also add TORCHDYNAMO_EXTENDED_DEBUG_CREATE_SYMBOL="u0"
# If you suspect the guard was triggered from C++, add TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
# For more debugging help, see https://docs.google.com/document/d/1HSuTTVvYH1pTew89Rtpeu84Ht3nQEFTYhAX3Ypa_xJs/edit?usp=sharing
#
# For C++ stack trace, run with TORCHDYNAMO_EXTENDED_DEBUG_CPP=1
#
# The following call raised this error:
#   File "D:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\segment_anything\utils\onnx.py", line 85, in mask_postprocessing
#     masks = masks[..., : prepadded_size[0], : prepadded_size[1]]  # type: ignore
#
#
# The error above occurred when calling torch.export.export. If you would like to view some more information about this error, and get a list of all other errors that may occur in your export call, you can replace your `export()` call with `draft_export()`.
#
# (Refer to the full stack trace above for more information.)

# %% [markdown]
# If desired, the model can additionally be quantized and optimized. We find this improves web runtime significantly for negligible change in qualitative performance. Run the next cell to quantize the model, or skip to the next section otherwise.

# %%
onnx_model_quantized_path = "sam_onnx_quantized_example.onnx"
quantize_dynamic(
    model_input=onnx_model_path,
    model_output=onnx_model_quantized_path,
    # optimize_model=True,
    per_channel=False,
    reduce_range=False,
    weight_type=QuantType.QUInt8,
)
onnx_model_path = onnx_model_quantized_path
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 onnx_model_quantized_path = "sam_onnx_quantized_example.onnx"
# ----> 2 quantize_dynamic(
#       3     model_input=onnx_model_path,
#       4     model_output=onnx_model_quantized_path,
#       5     # optimize_model=True,
#       6     per_channel=False,
#       7     reduce_range=False,
#       8     weight_type=QuantType.QUInt8,
#       9 )
#      10 onnx_model_path = onnx_model_quantized_path
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\onnxruntime\quantization\quantize.py:875, in quantize_dynamic(model_input, model_output, op_types_to_quantize, per_channel, reduce_range, weight_type, nodes_to_quantize, nodes_to_exclude, use_external_data_format, extra_options)
#     872 if "MatMulConstBOnly" not in extra_options:
#     873     extra_options["MatMulConstBOnly"] = True
# --> 875 model = update_opset_version(model, weight_type)
#     877 quantizer = ONNXQuantizer(
#     878     model,
#     879     per_channel,
#    (...)    889     extra_options,
#     890 )
#     892 quantizer.quantize_model()
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\onnxruntime\quantization\quant_utils.py:984, in update_opset_version(model, weight_type)
#     983 def update_opset_version(model: ModelProto, weight_type: QuantType) -> ModelProto:
# --> 984     opset_version = get_opset_version(model)
#     985     target_opset_version = opset_version
#     986     weight_quant_type = getattr(weight_type, "tensor_type", weight_type)
#
# File d:\HCMUS\2025-2026_HK1\ImageProcessing\Seminar-Segment-Anything-Model\Source_code\venv\Lib\site-packages\onnxruntime\quantization\quant_utils.py:977, in get_opset_version(model)
#     975 ai_onnx_domain = [opset for opset in model.opset_import if not opset.domain or opset.domain == "ai.onnx"]
#     976 if len(ai_onnx_domain) != 1:
# --> 977     raise ValueError("Failed to find proper ai.onnx domain")
#     978 opset_version = ai_onnx_domain[0].version
#     980 return opset_version
#
# ValueError: Failed to find proper ai.onnx domain

# %% [markdown]
# ## Example Image

# %%
image = cv2.imread('images/truck.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis('on')
plt.show()

# %% [markdown]
# ## Using an ONNX model

# %% [markdown]
# Here as an example, we use `onnxruntime` in python on CPU to execute the ONNX model. However, any platform that supports an ONNX runtime could be used in principle. Launch the runtime session below:

# %%
ort_session = onnxruntime.InferenceSession(onnx_model_path)

# %% [markdown]
# To use the ONNX model, the image must first be pre-processed using the SAM image encoder. This is a heavier weight process best performed on GPU. SamPredictor can be used as normal, then `.get_image_embedding()` will retreive the intermediate features.

# %%
sam.to(device='cuda')
predictor = SamPredictor(sam)

# %%
predictor.set_image(image)

# %%
image_embedding = predictor.get_image_embedding().cpu().numpy()

# %%
image_embedding.shape

# %% [markdown]
# The ONNX model has a different input signature than `SamPredictor.predict`. The following inputs must all be supplied. Note the special cases for both point and mask inputs. All inputs are `np.float32`.
# * `image_embeddings`: The image embedding from `predictor.get_image_embedding()`. Has a batch index of length 1.
# * `point_coords`: Coordinates of sparse input prompts, corresponding to both point inputs and box inputs. Boxes are encoded using two points, one for the top-left corner and one for the bottom-right corner. *Coordinates must already be transformed to long-side 1024.* Has a batch index of length 1.
# * `point_labels`: Labels for the sparse input prompts. 0 is a negative input point, 1 is a positive input point, 2 is a top-left box corner, 3 is a bottom-right box corner, and -1 is a padding point. *If there is no box input, a single padding point with label -1 and coordinates (0.0, 0.0) should be concatenated.*
# * `mask_input`: A mask input to the model with shape 1x1x256x256. This must be supplied even if there is no mask input. In this case, it can just be zeros.
# * `has_mask_input`: An indicator for the mask input. 1 indicates a mask input, 0 indicates no mask input.
# * `orig_im_size`: The size of the input image in (H,W) format, before any transformation.
#
# Additionally, the ONNX model does not threshold the output mask logits. To obtain a binary mask, threshold at `sam.mask_threshold` (equal to 0.0).

# %% [markdown]
# ### Example point input

# %%
input_point = np.array([[500, 375]])
input_label = np.array([1])

# %% [markdown]
# Add a batch index, concatenate a padding point, and transform.

# %%
onnx_coord = np.concatenate([input_point, np.array([[0.0, 0.0]])], axis=0)[None, :, :]
onnx_label = np.concatenate([input_label, np.array([-1])], axis=0)[None, :].astype(np.float32)

onnx_coord = predictor.transform.apply_coords(onnx_coord, image.shape[:2]).astype(np.float32)

# %% [markdown]
# Create an empty mask input and an indicator for no mask.

# %%
onnx_mask_input = np.zeros((1, 1, 256, 256), dtype=np.float32)
onnx_has_mask_input = np.zeros(1, dtype=np.float32)

# %% [markdown]
# Package the inputs to run in the onnx model

# %%
ort_inputs = {
    "image_embeddings": image_embedding,
    "point_coords": onnx_coord,
    "point_labels": onnx_label,
    "mask_input": onnx_mask_input,
    "has_mask_input": onnx_has_mask_input,
    "orig_im_size": np.array(image.shape[:2], dtype=np.float32)
}

# %% [markdown]
# Predict a mask and threshold it.

# %%
masks, _, low_res_logits = ort_session.run(None, ort_inputs)
masks = masks > predictor.model.mask_threshold

# %%
masks.shape

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
show_mask(masks, plt.gca())
show_points(input_point, input_label, plt.gca())
plt.axis('off')
plt.show()

# %% [markdown]
# ### Example mask input

# %%
input_point = np.array([[500, 375], [1125, 625]])
input_label = np.array([1, 1])

# Use the mask output from the previous run. It is already in the correct form for input to the ONNX model.
onnx_mask_input = low_res_logits

# %% [markdown]
# Transform the points as in the previous example.

# %%
onnx_coord = np.concatenate([input_point, np.array([[0.0, 0.0]])], axis=0)[None, :, :]
onnx_label = np.concatenate([input_label, np.array([-1])], axis=0)[None, :].astype(np.float32)

onnx_coord = predictor.transform.apply_coords(onnx_coord, image.shape[:2]).astype(np.float32)

# %% [markdown]
# The `has_mask_input` indicator is now 1.

# %%
onnx_has_mask_input = np.ones(1, dtype=np.float32)

# %% [markdown]
# Package inputs, then predict and threshold the mask.

# %%
ort_inputs = {
    "image_embeddings": image_embedding,
    "point_coords": onnx_coord,
    "point_labels": onnx_label,
    "mask_input": onnx_mask_input,
    "has_mask_input": onnx_has_mask_input,
    "orig_im_size": np.array(image.shape[:2], dtype=np.float32)
}

masks, _, _ = ort_session.run(None, ort_inputs)
masks = masks > predictor.model.mask_threshold

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
show_mask(masks, plt.gca())
show_points(input_point, input_label, plt.gca())
plt.axis('off')
plt.show()

# %% [markdown]
# ### Example box and point input

# %%
input_box = np.array([425, 600, 700, 875])
input_point = np.array([[575, 750]])
input_label = np.array([0])

# %% [markdown]
# Add a batch index, concatenate a box and point inputs, add the appropriate labels for the box corners, and transform. There is no padding point since the input includes a box input.

# %%
onnx_box_coords = input_box.reshape(2, 2)
onnx_box_labels = np.array([2,3])

onnx_coord = np.concatenate([input_point, onnx_box_coords], axis=0)[None, :, :]
onnx_label = np.concatenate([input_label, onnx_box_labels], axis=0)[None, :].astype(np.float32)

onnx_coord = predictor.transform.apply_coords(onnx_coord, image.shape[:2]).astype(np.float32)

# %% [markdown]
# Package inputs, then predict and threshold the mask.

# %%
onnx_mask_input = np.zeros((1, 1, 256, 256), dtype=np.float32)
onnx_has_mask_input = np.zeros(1, dtype=np.float32)

ort_inputs = {
    "image_embeddings": image_embedding,
    "point_coords": onnx_coord,
    "point_labels": onnx_label,
    "mask_input": onnx_mask_input,
    "has_mask_input": onnx_has_mask_input,
    "orig_im_size": np.array(image.shape[:2], dtype=np.float32)
}

masks, _, _ = ort_session.run(None, ort_inputs)
masks = masks > predictor.model.mask_threshold

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image)
show_mask(masks[0], plt.gca())
show_box(input_box, plt.gca())
show_points(input_point, input_label, plt.gca())
plt.axis('off')
plt.show()
